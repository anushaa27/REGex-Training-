# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset1 = pd.read_csv('heart.csv')
dataset2 = pd.read_csv('o2Saturation.csv')

# %%
dataset1.head(10)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
# 5   57    1   0     140   192    0        1       148     0      0.4    1
# 6   56    0   1     140   294    0        0       153     0      1.3    1
# 7   44    1   1     120   263    0        1       173     0      0.0    2
# 8   52    1   2     172   199    1        1       162     0      0.5    2
# 9   57    1   2     150   168    0        1       174     0      1.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1
# ...

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
print(dataset1.shape)
print(dataset2.shape)
# Out:
# (303, 14)
# (3585, 1)

# %% [markdown]
# # Descriptive Statistics

# %%
dataset1.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [raw]
# 1) Average age is 54 years and minimum age is 29 years. So, no children is involved in this data.
# 2) The average resting bp is 131 and its maximum value is 200.
# 3) The average cholestrol level is 126 and the maximum value is 564.
# 4) The average heart rate is 149 and the maximum is 200.

# %%
dataset1.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
dataset2.isnull().sum()
# Out:
# 98.6    0
# dtype: int64

# %% [raw]
# There are no missing values present in our data

# %%
data_numerical = [['age','trtbps','chol','thalachh','oldpeak']]
data_categorical = [['sex','cp','fbs','restecg','exng','caa','thall','output']]

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (8,6))
sns.heatmap(dataset1.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (10,6))
sns.countplot(x = 'sex' , hue = 'output' ,  data = dataset1)
plt.title("Distribution of Gender w.r.t. Heart Attack" , fontsize= 15)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.countplot(x = 'cp' , hue = 'output' ,  data = dataset1)
plt.title("Distribution of Chest Pain w.r.t. Heart Attack" , fontsize= 15)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.countplot(x = 'fbs' , hue = 'output' ,  data = dataset1)
plt.title("Distribution of fasting Blood Sugar w.r.t. Heart Attack" , fontsize= 15)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.countplot(x = 'restecg' , hue = 'output' ,  data = dataset1)
plt.title("Distribution of Resting Electrocardiographic results w.r.t. Heart Attack" , fontsize= 15)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.countplot(x = 'exng' , hue = 'output' ,  data = dataset1)
plt.title("Distribution of Exercise Induced Angina  w.r.t. Heart Attack" , fontsize= 15)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.countplot(x = 'caa' , hue = 'output' ,  data = dataset1)
plt.title("Distribution of no. of major blood vessels w.r.t. Heart Attack" , fontsize= 15)
plt.show()

# %%
dataset1.loc[dataset1['age']<=20,'age']=0
dataset1.loc[(dataset1['age']>20 )& (dataset1['age']<=40),'age'] =1
dataset1.loc[(dataset1['age']>40)&(dataset1['age']<=60),'age'] =2
dataset1.loc[dataset1['age']>60,'age'] =3

# %%
sns.countplot(x='age',data = dataset1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
plt.figure(figsize = (9,5))
sns.histplot(data = dataset1, x = "age", hue = "output", binwidth = 2) 
plt.title("Distribution of Age w.r.t Heart Attack")
plt.show()

# %%
sns.pairplot(dataset1[['age','trtbps','chol','thalachh','oldpeak','output']] , hue = 'output')
plt.show()

# %%
dataset1.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0    3    1   3     145   233    1        0       150     0      2.3    0
# 1    1    1   2     130   250    0        1       187     0      3.5    0
# 2    2    0   1     130   204    0        0       172     0      1.4    2
# 3    2    1   1     120   236    0        1       178     0      0.8    2
# 4    2    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
drop_cols = ['chol','trtbps','oldpeak','thalachh']
data = dataset1.drop(drop_cols, axis =1)

# %%
data.head()
# Out:
#    age  sex  cp  fbs  restecg  exng  slp  caa  thall  output
# 0    3    1   3    1        0     0    0    0      1       1
# 1    1    1   2    0        1     0    0    0      2       1
# 2    2    0   1    0        0     0    2    0      2       1
# 3    2    1   1    0        1     0    2    0      2       1
# 4    2    0   0    0        1     1    2    0      2       1

# %% [markdown]
# # Linear Regression

# %%
X_train = data.drop(['output'],axis =1).values
Y_train = data['output'].values

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X_train, Y_train, test_size = 0.20)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test , y_test)
# Out:
# 0.317034624306872

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 0.2719352 ,  0.96701719,  0.56545951,  0.95292968,  0.28101199,
#         0.69518449,  0.0625179 ,  0.21074148,  0.32025234,  0.89819661,
#         0.76821667,  0.83847797,  0.14886505,  0.83159084,  0.481738  ,
#         0.70879005,  1.06956183,  0.91010367,  0.29611487,  0.58647121,
#         0.48524817,  0.03785067,  1.00847378,  0.55829381,  0.22162243,
#         0.42923557,  0.59482029,  0.65455334,  0.9186893 ,  0.23868234,
#         0.374971  ,  0.17748862,  0.71292753, -0.08077558,  0.13771851,
#         0.08387291,  0.23388313,  0.17748862,  1.09485374,  0.97560282,
#         0.67891415,  0.62688022,  0.660825  ,  1.05680167,  0.14630414,
#         1.15176726,  1.20930545,  0.95459111,  0.84065842,  0.60387442,
#         0.42604855,  0.65601401,  0.72402626,  0.00497971,  0.61948752,
#         0.37998173, -0.07523162,  0.73393923, -0.05610835,  0.41285269,
#         1.03731555])

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7540983606557377
